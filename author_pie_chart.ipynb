# %%
#將檔案匯入
import pandas as pd 
data = pd.read_excel(r"C:\Users\User\Desktop\workshop\drive-download-20220120T032909Z-001\MilkTea_cleaned.xlsx")
data
# Out:
#                                                標題  \
# 0      好市多新霸主！開店5分鐘民眾掃光「厚奶茶」 #吐司切編：請各位大德行行好，小編...
# 1      好市多新霸主！開店5分鐘民眾掃光「厚奶茶」 #吐司切編：請各位大德行行，好小編...
# 2             這畫面也太誇張了吧小編還沒嚐鮮過欸(#小呆) #請分享#好市多#...
# 3        #奶茶不敗#厚奶茶到底多厚這裡獨賣   http://pics.ee/11...
# 4             這奔跑的程度.....到底是有多好喝RRRRRR精選新聞報你知→...
# ...                                           ...
# 82978  這股厚奶茶風潮還會延燒多久呢？　#鬼編　 【直擊片】好市多搶奶茶　闖進出口手刀...
# 82979  綠豆直擊：今早好市多嘉義店09:30開門，09:35厚奶茶賣完。 ＃左進右出喔...
# 82980                       好市多新霸主！開店5分鐘民眾掃光「厚奶茶」
# 82981  義美厚奶茶值得搶購嗎？市售奶茶大評比！ #藍編：覺得全家的義美就很好喝了啊～ ...
# 82982      美式賣場搶翻天！超夯厚奶茶盲測#摸摸：小編比較在意Costco到底怎念...
#
#                                                       內容    來源        平台  \
# 0      好市多新霸主！開店5分鐘民眾掃光「厚奶茶」 #吐司切編：請各位大德行行好，小編都還沒喝過XD...  社群網站  Facebook
# 1      好市多新霸主！開店5分鐘民眾掃光「厚奶茶」 #吐司切編：請各位大德行行，好小編都還沒喝過XD...  社群網站  Facebook
# 2      這畫面也太誇張了吧小編還沒嚐鮮過欸(#小呆) #請分享#好市多#厚奶茶#搶購影片來源：爆料公...  社群網站  Facebook
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82983 entries, 0 to 82982
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   標題      82983 non-null  object
#  1   內容      82975 non-null  object
#  2   來源      82983 non-null  object
#  3   平台      82983 non-null  object
#  4   頻道      82983 non-null  object
#  5   主文/回文   82983 non-null  object
#  6   發佈時間    82983 non-null  object
#  7   討論串總則數  82983 non-null  int64
#  8   作者      82983 non-null  object
#  9   原始連結    82983 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 6.3+ MB

# %%
#收集有哪些平台並創建dict
author_kind =  set(data["作者"])
author_dict = {}
for i in author_kind:
    author_dict[i]=0
author_dict
# Out:
# {'賴雅秀': 0,
#  'Jason Cscaoe': 0,
#  'Inn Zhang': 0,
#  'Zine Wang': 0,
#  'Kevin Edward Wang': 0,
#  '林彥慧': 0,
#  '劉昕': 0,
#  '簡勝也': 0,
#  '江筱豔': 0,
#  'easych': 0,
#  '丘峰竹': 0,
#  '賈修': 0,
#  '林育姍': 0,
#  '張純': 0,
#  '丁兒': 0,
#  '林鈺筑': 0,
#  '謝宛茹': 0,
#  'Yan Bin Chang': 0,
#  '劉千慈': 0,
#  '姜蘋': 0,
#  '陳閔琮': 0,
#  '莎拉媽媽育兒插畫': 0,
#  '林煒程': 0,
#  '羊樂樂': 0,
#  '徐胚逆': 0,
#  '翁乙文': 0,
#  '陳威力': 0,
#  'Chun Yao': 0,
#  '邱彥軒': 0,
#  'Nicky Chien': 0,
#  'Kay J Wu': 0,
#  '曾子浤': 0,
#  '張如花': 0,
#  '新井由華': 0,
#  '水優桂': 0,
#  'Annie Lei': 0,
#  '大牌貞': 0,
#  '吳小月': 0,
#  'Ruru Chang': 0,
#  'Susu Xuan': 0,
#  '黃偉恩': 0,
#  'Chilu Lu': 0,
#  'Ethan Lai': 0,
#  'KeVin Lei': 0,
#  '徐淳育': 0,
#  '蔡均富': 0,
#  '黃敏雄': 0,
#  'Chin Wei Hsu': 0,
#  '明權': 0,
#  'Juliet Ting': 0,
#  'virtueKyoKo': 0,
#  '愛甘': 0,
#  'Chen Q-y': 0,
#  '雯蘇': 0,
#  'Evan Hsieh': 0,
#  '施丘蕉萍': 0,
#  'neveneve': 0,
#  '陳嘉彬': 0,
#  '林瑞彬': 0,
#  '陳秀花': 0,
#  '依玫': 0,
#  '33689 27': 0,
#  '曾映潔': 0,
#  'JC Hsieh': 0,
#  'Pei Lu': 0,
# ...

# %%
#計算各平台的討論串總則數以當作熱度依據
def author_count(df):
    if df["主文/回文"]=="主文":
        author_dict[df["作者"]] += int(df["討論串總則數"])
data.apply(author_count,axis=1)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 82978    None
# 82979    None
# 82980    None
# 82981    None
# 82982    None
# Length: 82983, dtype: object

# %%
#將dict轉變成dataframe 方便觀看和畫圖
author_df = pd.DataFrame(author_dict,index=["Popularity"]).T
author_df = author_df.sort_values(by=["Popularity"],ascending = False)
author_df.head(10)
# Out:
#                Popularity
# 東森新聞                27158
# 台灣蘋果日報              10213
# 快點TV                10068
# TVBS 新聞              9651
# 下午茶星聞                5570
# ETNEWS新聞雲            5434
# 新聞龍捲風                4069
# 蘋果日報即時新聞             3383
# 即新聞                  2804
# Chiayi,Taiwan        2438

# %%
#分析個平台熱門程度(以圓餅圖呈現)
import matplotlib.pyplot as plt
label_list = author_df.index[:6]
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] 
plt.pie(author_df["Popularity"][:6],labels = label_list,autopct='%1.2f%%')
plt.title('作者熱度')
plt.show()
